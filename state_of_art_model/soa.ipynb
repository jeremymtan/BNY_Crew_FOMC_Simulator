# %% [markdown]
# # Ordinal Forest SOA Model Replication from Paper

# %% [markdown]
# ## Prep Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')


X = pd.read_csv("predictor_df.csv", parse_dates=['index'])
X.rename(columns={'index': 'Quarter'}, inplace=True)

X['Quarter'] = X['Quarter'].dt.to_period('Q')
# last row isn't needed, uncessary
X = X.iloc[:-1, :]

y = pd.read_csv("fomc_meetings.csv", parse_dates=['Date'])  # meeting dates + decision

# convert date to quarter accroding to apper
y['Quarter'] = y['Date'].dt.to_period('Q')
df = y.merge(X, on='Quarter', how='left')

df.tail()
# Out:
#           Date    Outcome Quarter  CPIAUCSL_QoQ  CPILFESL_QoQ  PPIACO_QoQ  \
# 250 2024-09-18        CUT  2024Q3      0.549291      0.782803   -1.262924
# 251 2024-11-07        CUT  2024Q4      0.874064      0.767061    0.297607
# 252 2024-12-18        CUT  2024Q4      0.874064      0.767061    0.297607
# 253 2025-01-29  NO CHANGE  2025Q1      0.633495      0.730909    2.131916
# 254 2025-03-19  NO CHANGE  2025Q1      0.633495      0.730909    2.131916
#
#       CL=F_QoQ   GDP_QoQ  GDPC1_QoQ  INDPRO_QoQ  ...  TB6SMFFM  T10Y2Y  T2Y3M  \
# 250 -16.396864  1.234461   0.759510   -0.637267  ...     -0.71    0.15  -1.30
# 251   5.207574  1.187918   0.607065    0.509087  ...     -0.29    0.33  -0.16
# 252   5.207574  1.187918   0.607065    0.509087  ...     -0.29    0.33  -0.16
# 253  -0.334632  0.000000   0.000000    0.748174  ...     -0.23    0.34  -0.37
# 254  -0.334632  0.000000   0.000000    0.748174  ...     -0.23    0.34  -0.37
#
#      T5Y2Y  prev1_decision  prev2_decision  unemp_idx  b_idx  ir_idx   pmi_QoQ
# 250  -0.12            5.33            5.33      101.0   79.0   122.0 -1.656315
# 251   0.02            4.64            4.83       99.0   85.0   121.0  3.578947
# 252   0.02            4.64            4.83       99.0   85.0   121.0  3.578947
# 253   0.07            4.33            4.33       86.0   75.0   103.0 -0.406504
# 254   0.07            4.33            4.33       86.0   75.0   103.0 -0.406504
#
# [5 rows x 30 columns]

# %%
# label for ordinal
label_map = {'CUT': 0, 'NO CHANGE': 1, 'HIKE': 2}
df['target'] = df['Outcome'].map(label_map)
df[['Quarter', 'target']].tail()
# Out:
#     Quarter  target
# 250  2024Q3       0
# 251  2024Q4       0
# 252  2024Q4       0
# 253  2025Q1       1
# 254  2025Q1       1

# %%
exclude_cols = ['Date', 'Quarter', 'Decision', 'target', 'Outcome']
feature_cols = [col for col in df.columns if col not in exclude_cols]
df = df.sort_values('Date')

# %% [markdown]
# ## Ordinal Forest Model with Recursive Training Data for One-step-ahead Forecasts

# %%
# !pip install orf
import orf

# CHANGE THIS if you want to predict on more observations
start_date = pd.Timestamp('2018-01-01')
test_mask = df['Date'] >= start_date

train_df = df[~test_mask]
test_df = df[test_mask]

print(f"Training on data before January 2018: {len(train_df)} observations")
print(f"Testing on data from January 2018 onwards: {len(test_df)} observations")


y_true = []
y_pred = []

# have to recursively fit the model as we use all past observations before the meeitng to predict
for i, (_, row) in enumerate(test_df.iterrows()):
    current_date = row['Date']
    print(f"Forecasting for observation {i+1}/{len(test_df)}, date: {current_date}")
    
    one_month_before = current_date - pd.DateOffset(months=1)
    
    train_mask = df['Date'] <= one_month_before
    X_train = df[train_mask][feature_cols]
    y_train = df[train_mask]['target']
    
    X_test = row[feature_cols].to_frame().T
    y_test = row['target']
    
    # THIS MAY NOT BE THE RIGHT CHOICE BUT ENDED UP JSUT IMPUTING AS THE STOCK DATA IS MISSING SOME OBSERVATIONS
    X_train = X_train.fillna(method='ffill').fillna(X_train.mean())
    X_test = X_test.fillna(X_train.mean())  
    
    # PARAMAERS MAY DIFFER FROM THE PAPER
    oforest = orf.OrderedForest(
        n_estimators=1000,
        min_samples_leaf=5,
        max_features=3,
        replace=False,
        sample_fraction=0.8,
        honesty=True,
        honesty_fraction=0.5,
        inference=False,
        n_jobs=-1,
        random_state=42
    )
    
    oforest.fit(X=X_train, y=y_train)
    

    pred_probs = oforest.predict(X=X_test, prob=True)
    pred = pred_probs['predictions'].argmax(axis=1)[0]
    
    y_true.append(y_test)
    y_pred.append(pred)
    
    print(f"Actual: {list(label_map.keys())[y_test]}, Predicted: {list(label_map.keys())[pred]}")
    print(f"Training data size: {len(X_train)} observations")
    print("-" * 50)

label_inverse = {0: 'CUT', 1: 'NO CHANGE', 2: 'HIKE'}
y_true_labels = [label_inverse[y] for y in y_true]
y_pred_labels = [label_inverse[y] for y in y_pred]

print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred, target_names=["Cut", "No change", "Hike"]))

print("\n=== Confusion Matrix ===")
conf_matrix = confusion_matrix(y_true, y_pred)
print(conf_matrix)
# Out:
# Training on data before January 2018: 196 observations
# Testing on data from January 2018 onwards: 59 observations
# Forecasting for observation 1/59, date: 2018-01-31 00:00:00
# Actual: NO CHANGE, Predicted: HIKE
# Training data size: 196 observations
# --------------------------------------------------
# Forecasting for observation 2/59, date: 2018-03-21 00:00:00
# Actual: HIKE, Predicted: NO CHANGE
# Training data size: 197 observations
# --------------------------------------------------
# Forecasting for observation 3/59, date: 2018-05-02 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 198 observations
# --------------------------------------------------
# Forecasting for observation 4/59, date: 2018-06-13 00:00:00
# Actual: HIKE, Predicted: NO CHANGE
# Training data size: 199 observations
# --------------------------------------------------
# Forecasting for observation 5/59, date: 2018-08-01 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 200 observations
# --------------------------------------------------
# Forecasting for observation 6/59, date: 2018-09-26 00:00:00
# Actual: HIKE, Predicted: NO CHANGE
# Training data size: 201 observations
# --------------------------------------------------
# Forecasting for observation 7/59, date: 2018-11-08 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 202 observations
# --------------------------------------------------
# Forecasting for observation 8/59, date: 2018-12-19 00:00:00
# Actual: HIKE, Predicted: NO CHANGE
# Training data size: 203 observations
# --------------------------------------------------
# Forecasting for observation 9/59, date: 2019-01-30 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 204 observations
# --------------------------------------------------
# Forecasting for observation 10/59, date: 2019-03-20 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 205 observations
# --------------------------------------------------
# Forecasting for observation 11/59, date: 2019-05-01 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 206 observations
# --------------------------------------------------
# Forecasting for observation 12/59, date: 2019-06-19 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 207 observations
# --------------------------------------------------
# Forecasting for observation 13/59, date: 2019-07-31 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 208 observations
# --------------------------------------------------
# Forecasting for observation 14/59, date: 2019-09-18 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 209 observations
# --------------------------------------------------
# Forecasting for observation 15/59, date: 2019-10-30 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 210 observations
# --------------------------------------------------
# Forecasting for observation 16/59, date: 2019-12-11 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 211 observations
# --------------------------------------------------
# Forecasting for observation 17/59, date: 2020-01-29 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 212 observations
# --------------------------------------------------
# Forecasting for observation 18/59, date: 2020-03-03 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 213 observations
# --------------------------------------------------
# Forecasting for observation 19/59, date: 2020-03-15 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 213 observations
# --------------------------------------------------
# Forecasting for observation 20/59, date: 2020-04-29 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 215 observations
# --------------------------------------------------
# Forecasting for observation 21/59, date: 2020-06-10 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 216 observations
# --------------------------------------------------
# Forecasting for observation 22/59, date: 2020-07-29 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 217 observations
# --------------------------------------------------
# Forecasting for observation 23/59, date: 2020-09-16 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 218 observations
# --------------------------------------------------
# Forecasting for observation 24/59, date: 2020-11-05 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 219 observations
# --------------------------------------------------
# Forecasting for observation 25/59, date: 2020-12-16 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 220 observations
# --------------------------------------------------
# Forecasting for observation 26/59, date: 2021-01-27 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 221 observations
# --------------------------------------------------
# Forecasting for observation 27/59, date: 2021-03-17 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 222 observations
# --------------------------------------------------
# Forecasting for observation 28/59, date: 2021-04-28 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 223 observations
# --------------------------------------------------
# Forecasting for observation 29/59, date: 2021-06-16 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 224 observations
# --------------------------------------------------
# Forecasting for observation 30/59, date: 2021-07-28 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 225 observations
# --------------------------------------------------
# Forecasting for observation 31/59, date: 2021-09-22 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 226 observations
# --------------------------------------------------
# Forecasting for observation 32/59, date: 2021-11-03 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 227 observations
# --------------------------------------------------
# Forecasting for observation 33/59, date: 2021-12-15 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 228 observations
# --------------------------------------------------
# Forecasting for observation 34/59, date: 2022-01-26 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 229 observations
# --------------------------------------------------
# Forecasting for observation 35/59, date: 2022-03-16 00:00:00
# Actual: HIKE, Predicted: NO CHANGE
# Training data size: 230 observations
# --------------------------------------------------
# Forecasting for observation 36/59, date: 2022-05-04 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 231 observations
# --------------------------------------------------
# Forecasting for observation 37/59, date: 2022-06-15 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 232 observations
# --------------------------------------------------
# Forecasting for observation 38/59, date: 2022-07-27 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 233 observations
# --------------------------------------------------
# Forecasting for observation 39/59, date: 2022-09-21 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 234 observations
# --------------------------------------------------
# Forecasting for observation 40/59, date: 2022-11-02 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 235 observations
# --------------------------------------------------
# Forecasting for observation 41/59, date: 2022-12-14 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 236 observations
# --------------------------------------------------
# Forecasting for observation 42/59, date: 2023-02-01 00:00:00
# Actual: HIKE, Predicted: NO CHANGE
# Training data size: 237 observations
# --------------------------------------------------
# Forecasting for observation 43/59, date: 2023-03-22 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 238 observations
# --------------------------------------------------
# Forecasting for observation 44/59, date: 2023-05-03 00:00:00
# Actual: HIKE, Predicted: HIKE
# Training data size: 239 observations
# --------------------------------------------------
# Forecasting for observation 45/59, date: 2023-06-14 00:00:00
# Actual: NO CHANGE, Predicted: HIKE
# Training data size: 240 observations
# --------------------------------------------------
# Forecasting for observation 46/59, date: 2023-07-26 00:00:00
# Actual: HIKE, Predicted: NO CHANGE
# Training data size: 241 observations
# --------------------------------------------------
# Forecasting for observation 47/59, date: 2023-09-20 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 242 observations
# --------------------------------------------------
# Forecasting for observation 48/59, date: 2023-11-01 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 243 observations
# --------------------------------------------------
# Forecasting for observation 49/59, date: 2023-12-13 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 244 observations
# --------------------------------------------------
# Forecasting for observation 50/59, date: 2024-01-31 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 245 observations
# --------------------------------------------------
# Forecasting for observation 51/59, date: 2024-03-20 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 246 observations
# --------------------------------------------------
# Forecasting for observation 52/59, date: 2024-05-01 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 247 observations
# --------------------------------------------------
# Forecasting for observation 53/59, date: 2024-06-12 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 248 observations
# --------------------------------------------------
# Forecasting for observation 54/59, date: 2024-07-31 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 249 observations
# --------------------------------------------------
# Forecasting for observation 55/59, date: 2024-09-18 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 250 observations
# --------------------------------------------------
# Forecasting for observation 56/59, date: 2024-11-07 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 251 observations
# --------------------------------------------------
# Forecasting for observation 57/59, date: 2024-12-18 00:00:00
# Actual: CUT, Predicted: NO CHANGE
# Training data size: 252 observations
# --------------------------------------------------
# Forecasting for observation 58/59, date: 2025-01-29 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 253 observations
# --------------------------------------------------
# Forecasting for observation 59/59, date: 2025-03-19 00:00:00
# Actual: NO CHANGE, Predicted: NO CHANGE
# Training data size: 254 observations
# --------------------------------------------------
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#          Cut       0.00      0.00      0.00         8
#    No change       0.69      0.94      0.80        36
#         Hike       0.80      0.53      0.64        15
#
#     accuracy                           0.71        59
#    macro avg       0.50      0.49      0.48        59
# weighted avg       0.63      0.71      0.65        59
#
#
# === Confusion Matrix ===
# [[ 0  8  0]
#  [ 0 34  2]
#  [ 0  7  8]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 82
#      79 print(conf_matrix)
#      81 # Calculate class-specific and overall accuracy (as in the paper)
# ---> 82 class_correct = np.diag(conf_matrix)
#      83 class_total = np.sum(conf_matrix, axis=1)
#      84 class_accuracy = class_correct / class_total * 100
#
# NameError: name 'np' is not defined

# %%
import numpy as np

class_correct = np.diag(conf_matrix)
class_total = np.sum(conf_matrix, axis=1)
class_accuracy = class_correct / class_total * 100

print("\n=== Accuracy by Class ===")
for i, label in enumerate(["Cut", "No change", "Hike"]):
    if class_total[i] > 0:  
        print(f"{label}: {class_accuracy[i]:.1f}%")
    # shouldn't happen
    else:
        print(f"{label}: N/A (no observations)")

overall_accuracy = np.sum(class_correct) / np.sum(class_total) * 100
print(f"Overall Accuracy: {overall_accuracy:.1f}%")

# export
results_df = pd.DataFrame({
    'Date': test_df['Date'].reset_index(drop=True),
    'Actual': y_true_labels,
    'Predicted': y_pred_labels,
    'Correct': [a == p for a, p in zip(y_true_labels, y_pred_labels)]
})
# Out:
# === Accuracy by Class ===
# Cut: 0.0%
# No change: 94.4%
# Hike: 53.3%
# Overall Accuracy: 71.2%

# %%
results_df.to_csv("fomc_forecast_results_2018onwards.csv", index=False)

# %% [markdown]
# ## Differences in Implementation

# %% [markdown]
# 1. Software implementation: The original paper uses the R package "ordinalForest" while our implementation uses a Python package. This may result in some algorithmic differences despite similar conceptual approaches.
# 2. Time period: The original paper examines data from January 1994 to June 2022, while our implementation starts predictions from January 2018 onwards.
# 3. Parameter selection: The paper uses default parameters from the R implementation, while our Python implementation uses similar but not identical parameters.
# 4. Feature selection: The paper carefully constructs 45 specific predictor variables with both year-over-year and quarter-over-quarter transformations. Our implementation uses only tests quater-over-quarter transformations.
# 5. Evaluation metrics: We've implemented the same evaluation approach as the paper, looking at class-specific and overall accuracy.
# 6. Fixed window vs Increasing Window: The paper tested both approaches but we only did the increasing window.
