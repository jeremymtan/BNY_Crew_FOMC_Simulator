# %%
import json
from collections import Counter
import numpy as np
import glob

meeting_date = "May 2023"
correct_vote = "0.25%"

# Define data to store in a JSON file
data = {
    "exact_historical_dates_referenced": ["1980s", "post-2008"],
    "exact_metrics_mentioned": [
        "CPI",
        "PCE",
        "unemployment rate",
        "consumer sentiment surveys",
    ],
    "rate_votes": [
        {"member": "Federal Open Market Committee Chair", "vote": "0.00%"},
        {"member": "Vice Chair of the Federal Reserve", "vote": "0.00%"},
        {"member": "Minneapolis Fed President - Inflation Hawk", "vote": "0.00%"},
        {"member": "FOMC Member Michael Barr", "vote": "0.00%"},
        {"member": "Regional Bank President - Dallas", "vote": "0.00%"},
        {"member": "FOMC Member Michelle Bowman", "vote": "0.00%"},
        {"member": "FOMC Member Lisa Cook", "vote": "0.00%"},
        {"member": "Regional Bank President - Chicago", "vote": "0.00%"},
        {"member": "FOMC Member Philip Jefferson", "vote": "0.00%"},
        {"member": "FOMC Member Adriana Kugler", "vote": "0.00%"},
        {"member": "FOMC Member Christopher Waller", "vote": "0.00%"},
        {"member": "Regional Bank President - Philadelphia", "vote": "0.00%"},
    ],
    "rate_predictions": [
        {"member": "Federal Open Market Committee Chair", "prediction": "3.25%"},
        {"member": "Vice Chair of the Federal Reserve", "prediction": "3.75%"},
        {"member": "Minneapolis Fed President - Inflation Hawk", "prediction": "3.75%"},
        {"member": "FOMC Member Michael Barr", "prediction": "3.75%"},
        {"member": "Regional Bank President - Dallas", "prediction": "3.75%"},
        {"member": "FOMC Member Michelle Bowman", "prediction": "3.75%"},
        {"member": "FOMC Member Lisa Cook", "prediction": "3.75%"},
        {"member": "Regional Bank President - Chicago", "prediction": "3.75%"},
        {"member": "FOMC Member Philip Jefferson", "prediction": "3.75%"},
        {"member": "FOMC Member Adriana Kugler", "prediction": "3.75%"},
        {"member": "FOMC Member Christopher Waller", "prediction": "3.75%"},
        {"member": "Regional Bank President - Philadelphia", "prediction": "3.75%"},
    ],
}

# Save JSON data to a file
with open("rate_summary1.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

print("JSON file 1 saved successfully.")
# Out:
# JSON file 1 saved successfully.

# %%
# Define data to store in a JSON file
data = {
    "exact_historical_dates_referenced": ["1980-1982", "2008-2012", "1990-1999"],
    "exact_metrics_mentioned": ["CPI 303.365", "PCE 124.382", "Unemployment rate 3.7%"],
    "rate_votes": [
        {"member": "Federal Open Market Committee Chair", "vote": "0.00%"},
        {"member": "Vice Chair of the Federal Reserve", "vote": "0.00%"},
        {"member": "Minneapolis Fed President - Inflation Hawk", "vote": "0.00%"},
        {"member": "FOMC Member Michael Barr", "vote": "0.00%"},
        {"member": "Regional Bank President - Dallas", "vote": "0.00%"},
        {"member": "FOMC Member Michelle Bowman", "vote": "0.00%"},
        {"member": "FOMC Member Lisa Cook", "vote": "0.00%"},
        {"member": "Regional Bank President - Chicago", "vote": "0.00%"},
        {"member": "FOMC Member Philip Jefferson", "vote": "0.00%"},
        {"member": "FOMC Member Adriana Kugler", "vote": "0.00%"},
        {"member": "FOMC Member Christopher Waller", "vote": "0.00%"},
        {"member": "Regional Bank President - Philadelphia", "vote": "0.00%"},
    ],
    "rate_predictions": [
        {"member": "Federal Open Market Committee Chair", "prediction": "3.75%"},
        {"member": "Vice Chair of the Federal Reserve", "prediction": "3.50%"},
        {"member": "Minneapolis Fed President - Inflation Hawk", "prediction": "3.75%"},
        {"member": "FOMC Member Michael Barr", "prediction": "3.75%"},
        {"member": "Regional Bank President - Dallas", "prediction": "3.50%"},
        {"member": "FOMC Member Michelle Bowman", "prediction": "3.25%"},
        {"member": "FOMC Member Lisa Cook", "prediction": "3.50%"},
        {"member": "Regional Bank President - Chicago", "prediction": "3.50%"},
        {"member": "FOMC Member Philip Jefferson", "prediction": "3.75%"},
        {"member": "FOMC Member Adriana Kugler", "prediction": "3.50%"},
        {"member": "FOMC Member Christopher Waller", "prediction": "3.75%"},
        {"member": "Regional Bank President - Philadelphia", "prediction": "3.75%"},
    ],
}

# Save JSON data to a file
with open("rate_summary2.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

print("JSON file 2 saved successfully.")
# Out:
# JSON file 2 saved successfully.

# %%
# Define data to store in a JSON file
data = {
    "exact_historical_dates_referenced": [
        "early 1980s",
        "2018-2019",
        "post-2008 crisis",
    ],
    "exact_metrics_mentioned": ["3.7% unemployment", "2.88% GDP growth"],
    "rate_votes": [
        {"member": "Federal Open Market Committee Chair", "vote": "0.00%"},
        {"member": "Vice Chair of the Federal Reserve", "vote": "0.00%"},
        {"member": "Minneapolis Fed President - Inflation Hawk", "vote": "0.00%"},
        {"member": "FOMC Member Michael Barr", "vote": "0.00%"},
        {"member": "Regional Bank President - Dallas", "vote": "0.00%"},
        {"member": "FOMC Member Michelle Bowman", "vote": "0.00%"},
        {"member": "FOMC Member Lisa Cook", "vote": "0.00%"},
        {"member": "Regional Bank President - Chicago", "vote": "0.00%"},
        {"member": "FOMC Member Philip Jefferson", "vote": "0.00%"},
        {"member": "FOMC Member Adriana Kugler", "vote": "0.00%"},
        {"member": "FOMC Member Christopher Waller", "vote": "0.00%"},
        {"member": "Regional Bank President - Philadelphia", "vote": "0.00%"},
    ],
    "rate_predictions": [
        {"member": "Federal Open Market Committee Chair", "prediction": "2.75%"},
        {"member": "Vice Chair of the Federal Reserve", "prediction": "2.75%"},
        {"member": "Minneapolis Fed President - Inflation Hawk", "prediction": "2.75%"},
        {"member": "FOMC Member Michael Barr", "prediction": "2.75%"},
        {"member": "Regional Bank President - Dallas", "prediction": "2.75%"},
        {"member": "FOMC Member Michelle Bowman", "prediction": "2.75%"},
        {"member": "FOMC Member Lisa Cook", "prediction": "2.75%"},
        {"member": "Regional Bank President - Chicago", "prediction": "2.75%"},
        {"member": "FOMC Member Philip Jefferson", "prediction": "2.75%"},
        {"member": "FOMC Member Adriana Kugler", "prediction": "2.75%"},
        {"member": "FOMC Member Christopher Waller", "prediction": "2.75%"},
        {"member": "Regional Bank President - Philadelphia", "prediction": "2.75%"},
    ],
}

# Save JSON data to a file
with open("rate_summary3.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

print("JSON file 3 saved successfully.")
# Out:
# JSON file 3 saved successfully.

# %%
# Step 1: Get a list of all JSON files
json_files = glob.glob("rate_summary*.json")  # Adjust pattern to match your file names

# Step 2: Read all JSON files into a list
rate_summaries = []

for file in json_files:
    with open(file, "r") as f:
        data = json.load(f)
        rate_summaries.append(data)  # Append each JSON object to the list

# Print the collected rate summaries
print(json.dumps(rate_summaries, indent=4))
# Out:
# [
#     {
#         "exact_historical_dates_referenced": [
#             "1980s",
#             "post-2008"
#         ],
#         "exact_metrics_mentioned": [
#             "CPI",
#             "PCE",
#             "unemployment rate",
#             "consumer sentiment surveys"
#         ],
#         "rate_votes": [
#             {
#                 "member": "Federal Open Market Committee Chair",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Vice Chair of the Federal Reserve",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Minneapolis Fed President - Inflation Hawk",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Michael Barr",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Dallas",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Michelle Bowman",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Lisa Cook",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Chicago",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Philip Jefferson",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Adriana Kugler",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Christopher Waller",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Philadelphia",
#                 "vote": "0.00%"
#             }
#         ],
#         "rate_predictions": [
#             {
#                 "member": "Federal Open Market Committee Chair",
#                 "prediction": "3.25%"
#             },
#             {
#                 "member": "Vice Chair of the Federal Reserve",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "Minneapolis Fed President - Inflation Hawk",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Michael Barr",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "Regional Bank President - Dallas",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Michelle Bowman",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Lisa Cook",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "Regional Bank President - Chicago",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Philip Jefferson",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Adriana Kugler",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Christopher Waller",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "Regional Bank President - Philadelphia",
#                 "prediction": "3.75%"
#             }
#         ]
#     },
#     {
#         "exact_historical_dates_referenced": [
#             "early 1980s",
#             "2018-2019",
#             "post-2008 crisis"
#         ],
#         "exact_metrics_mentioned": [
#             "3.7% unemployment",
#             "2.88% GDP growth"
#         ],
#         "rate_votes": [
#             {
#                 "member": "Federal Open Market Committee Chair",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Vice Chair of the Federal Reserve",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Minneapolis Fed President - Inflation Hawk",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Michael Barr",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Dallas",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Michelle Bowman",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Lisa Cook",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Chicago",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Philip Jefferson",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Adriana Kugler",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Christopher Waller",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Philadelphia",
#                 "vote": "0.00%"
#             }
#         ],
#         "rate_predictions": [
#             {
#                 "member": "Federal Open Market Committee Chair",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "Vice Chair of the Federal Reserve",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "Minneapolis Fed President - Inflation Hawk",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "FOMC Member Michael Barr",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "Regional Bank President - Dallas",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "FOMC Member Michelle Bowman",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "FOMC Member Lisa Cook",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "Regional Bank President - Chicago",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "FOMC Member Philip Jefferson",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "FOMC Member Adriana Kugler",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "FOMC Member Christopher Waller",
#                 "prediction": "2.75%"
#             },
#             {
#                 "member": "Regional Bank President - Philadelphia",
#                 "prediction": "2.75%"
#             }
#         ]
#     },
#     {
#         "exact_historical_dates_referenced": [
#             "1980-1982",
#             "2008-2012",
#             "1990-1999"
#         ],
#         "exact_metrics_mentioned": [
#             "CPI 303.365",
#             "PCE 124.382",
#             "Unemployment rate 3.7%"
#         ],
#         "rate_votes": [
#             {
#                 "member": "Federal Open Market Committee Chair",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Vice Chair of the Federal Reserve",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Minneapolis Fed President - Inflation Hawk",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Michael Barr",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Dallas",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Michelle Bowman",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Lisa Cook",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Chicago",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Philip Jefferson",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Adriana Kugler",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "FOMC Member Christopher Waller",
#                 "vote": "0.00%"
#             },
#             {
#                 "member": "Regional Bank President - Philadelphia",
#                 "vote": "0.00%"
#             }
#         ],
#         "rate_predictions": [
#             {
#                 "member": "Federal Open Market Committee Chair",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "Vice Chair of the Federal Reserve",
#                 "prediction": "3.50%"
#             },
#             {
#                 "member": "Minneapolis Fed President - Inflation Hawk",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Michael Barr",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "Regional Bank President - Dallas",
#                 "prediction": "3.50%"
#             },
#             {
#                 "member": "FOMC Member Michelle Bowman",
#                 "prediction": "3.25%"
#             },
#             {
#                 "member": "FOMC Member Lisa Cook",
#                 "prediction": "3.50%"
#             },
#             {
#                 "member": "Regional Bank President - Chicago",
#                 "prediction": "3.50%"
#             },
#             {
#                 "member": "FOMC Member Philip Jefferson",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "FOMC Member Adriana Kugler",
#                 "prediction": "3.50%"
#             },
#             {
#                 "member": "FOMC Member Christopher Waller",
#                 "prediction": "3.75%"
#             },
#             {
#                 "member": "Regional Bank President - Philadelphia",
#                 "prediction": "3.75%"
#             }
#         ]
#     }
# ]

# %%
# Dictionary to store votes by member
votes_by_member = {}
predictions_by_member = {}
all_votes = []

# Loop through each JSON object
for summary in rate_summaries:
    for vote in summary["rate_votes"]:
        member = vote["member"]
        vote_value = vote["vote"]

        # Initialize list if member not in dictionary
        if member not in votes_by_member:
            votes_by_member[member] = []

        # Append vote to the corresponding member
        votes_by_member[member].append(vote_value)
        all_votes.append(vote_value)
    for prediction in summary["rate_predictions"]:
        member = prediction["member"]
        prediction_value = prediction["prediction"]

        # Initialize list if member not in dictionary
        if member not in predictions_by_member:
            predictions_by_member[member] = []

        # Append vote to the corresponding member
        predictions_by_member[member].append(prediction_value)

# %%
vote_agreement_rates = []
prediction_agreement_rates = []

for member in votes_by_member:
    vote_counts = Counter(votes_by_member[member])
    # Get the most common value and its count
    most_common_value, count = vote_counts.most_common(1)[0]
    vote_agreement_rates.append(100 * count / len(votes_by_member[member]))
    # Do the same for predictions
    prediction_counts = Counter(predictions_by_member[member])
    # Get the most common value and its count
    most_common_value, count = prediction_counts.most_common(1)[0]
    prediction_agreement_rates.append(100 * count / len(predictions_by_member[member]))
# print(vote_agreement_rates)
avg_vote_agreement = np.mean(vote_agreement_rates)
print(f"average agreement rate for votes: {avg_vote_agreement}%")
# print(prediction_agreement_rates)
avg_prediction_agreement = np.mean(prediction_agreement_rates)
print(
    f"average agreement rate for predictions: {np.round(avg_prediction_agreement,2)}%"
)
print(
    f"total agreement rate: {np.round(np.mean([avg_vote_agreement,avg_prediction_agreement]),2)}%"
)
correct_vote_pct = sum([vote == correct_vote for votes in all_votes]) / len(all_votes)
print(f"correct rate vote percentage = {correct_vote_pct}%")
# Out:
# average agreement rate for votes: 100.0%
# average agreement rate for predictions: 47.22%
# total agreement rate: 73.61%
# correct rate vote percentage = 0.0%

# %% [markdown]
# For each of 5 meetings
# - Grab input data for that meeting
# - run the meeting 5 times (clear memory)
# - take 5 json files and calculate the stats
